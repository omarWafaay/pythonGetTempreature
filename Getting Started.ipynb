# %% [markdown]
# # Installing meteostat package

# %%
# !pip install meteostat
# Out:
# Collecting meteostat
#   Downloading meteostat-1.6.5-py3-none-any.whl (31 kB)
# Requirement already satisfied: pandas>=1.1 in c:\users\omarh\anaconda3\lib\site-packages (from meteostat) (1.4.4)
# Requirement already satisfied: pytz in c:\users\omarh\anaconda3\lib\site-packages (from meteostat) (2022.1)
# Requirement already satisfied: numpy in c:\users\omarh\anaconda3\lib\site-packages (from meteostat) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\omarh\anaconda3\lib\site-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\omarh\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=1.1->meteostat) (1.16.0)
# Installing collected packages: meteostat
# Successfully installed meteostat-1.6.5

# %% [markdown]
# # Importing necessary packages

# %%
# Import Meteostat library and dependencies
from datetime import datetime,timedelta
import matplotlib.pyplot as plt
from meteostat import Point, Daily,Stations

# %%
# Set time period
"""
#You can choose relative dates from your current time, or choose specific dates
start = datetime(2018, 1, 1)
end = datetime(2018, 12, 31)
"""
start=datetime.now()
end=datetime.now()+timedelta(11)

# %%
#Chhosing the location
"""
You can add the required location using it's geographical coordinates using the Point() class, or by using the id of the weather station if known
"""
from geopy.geocoders import Nominatim

#initialize the Nominatim object
Nomi_locator = Nominatim(user_agent="My App")

address= "Alexandria,Egypt"

#get the location detail
location = Nomi_locator.geocode(address)
# point_location=Point(lat=location.latitude,lon=location.longitude,alt=location.altitude)
point_location=Point(lat=location.latitude,lon=location.longitude,)

# %%
# Get daily data for the selected period
data = Daily(point_location, start+timedelta(-1), end)
data = data.fetch()

# %%
data
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2023-04-14  18.2  12.4  23.7   0.0   NaN   86.0   8.7  27.8  1017.6   NaN
# 2023-04-15  19.9  15.5  25.0   0.0   NaN   59.0  12.1  31.5  1015.4   NaN
# 2023-04-16  20.5  14.8  26.4   NaN   NaN   61.0   9.6  27.8  1012.8   NaN
# 2023-04-17  22.2  15.7  29.3   NaN   NaN   83.0  11.1  29.6  1011.2   NaN
# 2023-04-18  23.0  17.1  29.9   NaN   NaN   71.0  11.4  27.8  1011.1   NaN
# 2023-04-19  21.2  18.7  24.1   NaN   NaN  346.0  15.2  31.5  1012.8   NaN
# 2023-04-20  20.3  17.5  23.8   NaN   NaN  335.0  17.3  37.0  1012.7   NaN
# 2023-04-21  19.2  16.4  22.1   NaN   NaN  325.0  17.2  35.2  1011.4   NaN
# 2023-04-22  19.4  16.1  23.1   NaN   NaN  317.0  15.1  33.3  1010.6   NaN

# %%
# Plot line chart including average, minimum and maximum temperature
data.plot(y = ['tavg', 'tmin', 'tmax'], kind = 'line')

# Show chart
plt.show()

# %%
#same id for Alexandria,Egypt
Daily('62318', start+timedelta(-1), end).fetch()
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2023-04-14  18.2  12.4  23.7   0.0   NaN   86.0   8.7  27.8  1017.6   NaN
# 2023-04-15  19.9  15.5  25.0   0.0   NaN   59.0  12.1  31.5  1015.4   NaN
# 2023-04-16  20.5  14.8  26.4   NaN   NaN   61.0   9.6  27.8  1012.8   NaN
# 2023-04-17  22.2  15.7  29.3   NaN   NaN   83.0  11.1  29.6  1011.2   NaN
# 2023-04-18  23.0  17.1  29.9   NaN   NaN   71.0  11.4  27.8  1011.1   NaN
# 2023-04-19  21.2  18.7  24.1   NaN   NaN  346.0  15.2  31.5  1012.8   NaN
# 2023-04-20  20.3  17.5  23.8   NaN   NaN  335.0  17.3  37.0  1012.7   NaN
# 2023-04-21  19.2  16.4  22.1   NaN   NaN  325.0  17.2  35.2  1011.4   NaN
# 2023-04-22  19.4  16.1  23.1   NaN   NaN  317.0  15.1  33.3  1010.6   NaN

# %%
#Try for Jeddah KSA
address= "Jeddah,KSA"

#get the location detail
location_jed = Nomi_locator.geocode(address)
# point_location=Point(lat=location.latitude,lon=location.longitude,alt=location.altitude)
point_location_jed=Point(lat=location_jed.latitude,lon=location_jed.longitude,)


data_jed = Daily(point_location_jed, start+timedelta(-1), end).fetch()
data_jed
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2023-04-14  27.9  23.9  32.1   0.0   NaN  329.0  17.8   NaN  1011.8   NaN
# 2023-04-15  29.4  27.5  31.8   0.0   NaN  295.0  11.9   NaN  1009.6   NaN
# 2023-04-16  29.3  26.3  32.3   NaN   NaN  320.0  12.7   NaN  1008.0   NaN
# 2023-04-17  30.2  26.6  34.0   NaN   NaN  335.0  14.4   NaN  1007.1   NaN
# 2023-04-18  30.6  26.6  34.9   NaN   NaN  326.0  13.7   NaN  1008.2   NaN
# 2023-04-19  31.3  27.5  35.0   NaN   NaN  330.0  13.9   NaN  1008.3   NaN
# 2023-04-20  32.0  28.1  36.1   NaN   NaN  333.0  12.6   NaN  1006.2   NaN
# 2023-04-21  31.6  28.2  35.3   NaN   NaN  345.0  12.3   NaN  1004.9   NaN
# 2023-04-22  30.3  26.4  34.4   NaN   NaN  214.0  13.3   NaN  1005.9   NaN

# %% [markdown]
# # Getting nearby stations

# %%
address= "Jeddah,KSA"

#get the location detail
location = Nomi_locator.geocode(address)
stations=Stations()
stations.nearby(lat=location.latitude,lon=location.longitude).fetch(10)
# Out:
#                                                name country region    wmo  \
# id
# 41026                                        Jeddah      SA     MK  41026
# 41024  Jeddah King Abdul Aziz International Airport      SA     ML  41024
# 41020                                Jeddah / I. E.      SA     ML  41020
# 41030                                        Makkah      SA     ML  41030
# 41036                                          Taif      SA     ML  41036
# 41006                                        Muwaih      SA     ML  41006
# 41055                                       Al Baha      SA     BH  41055
# 62641                                    Port Sudan      SD     RS  62641
# 40439                                         Yenbo      SA     MD  40439
# HSPN0                 Port Sudan / Siy?mt?t Tisim?t      SD     RS   <NA>
#
#        icao  latitude  longitude  elevation         timezone hourly_start  \
# id
# 41026  OEJD   21.5000    39.2000       15.0      Asia/Riyadh   1956-01-01
# 41024  OEJN   21.7000    39.1833       15.0      Asia/Riyadh   1983-01-01
# 41020  <NA>   21.4167    39.2167       10.0      Asia/Riyadh          NaT
# 41030  OEMK   21.4333    39.7667      310.0      Asia/Riyadh   2015-08-28
# 41036  OETF   21.4833    40.5500     1478.0      Asia/Riyadh   1983-01-01
# 41006  OEMH   22.4333    41.7500        0.0      Asia/Riyadh   1985-10-01
# 41055  OEBA   20.3000    41.6333     1652.0      Asia/Riyadh   1983-02-01
# 62641  HSSP   19.5833    37.2167        3.0  Africa/Khartoum   1949-02-05
# 40439  OEYN   24.1500    38.0667        8.0      Asia/Riyadh   1973-01-01
# HSPN0  HSPN   19.4333    37.2333      138.0  Africa/Khartoum   2005-01-15
#
#       hourly_end daily_start  daily_end monthly_start monthly_end  \
# id
# 41026 2003-02-13  1983-01-10 1983-02-25           NaT         NaT
# 41024 2023-04-13  1978-01-01 2023-03-23    1978-01-01  2022-01-01
# 41020        NaT         NaT        NaT           NaT         NaT
# 41030 2019-07-18  1983-08-01 2019-07-18    1983-01-01  2018-01-01
# 41036 2023-04-13  1983-01-01 2023-03-23    1982-01-01  2022-01-01
# 41006 2011-06-14         NaT        NaT    1995-01-01  1999-01-01
# 41055 2023-04-13  1983-02-02 2023-04-07    1982-01-01  2022-01-01
# 62641 2019-05-08  1957-07-01 2019-04-14    1949-01-01  2021-01-01
# 40439 2023-04-13  1973-01-01 2023-04-07    1974-01-01  2022-01-01
# HSPN0 2023-04-12         NaT        NaT           NaT         NaT
#
#             distance
# id
# 41026   11003.644951
# 41024   15708.056139
# 41020   19506.961207
# 41030   68148.285293
# 41036  147762.928973
# 41006  287200.963774
# 41055  296334.877921
# 62641  297029.507313
# 40439  306697.294085
# HSPN0  308588.480675

# %%
address= "Alexandria,Egypt"

#get the location detail
location = Nomi_locator.geocode(address)
stations=Stations()
stations.nearby(lat=location.latitude,lon=location.longitude).fetch(1)
# Out:
#                       name country region    wmo  icao  latitude  longitude  \
# id
# 62318  Alexandria / Nouzha      EG    IDR  62318  HEAX      31.2      29.95
#
#        elevation      timezone hourly_start hourly_end daily_start  daily_end  \
# id
# 62318       -2.0  Africa/Cairo   1937-01-03 2023-04-12  1957-01-01 2023-04-06
#
#       monthly_start monthly_end     distance
# id
# 62318    1949-01-01  2021-01-01  5215.666315

# %% [markdown]
# #  Getting the normal tempreature through a date range

# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Normals

# Get Normals data
data = Normals('10637', 1961, 1990)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()
